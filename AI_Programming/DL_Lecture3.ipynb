# %% [markdown]
# # Rogistic Regression
# ---

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.13.1-cp38-cp38-win_amd64.whl.metadata (2.6 kB)
# INFO: pip is looking at multiple versions of tensorflow to determine which version is compatible with other requirements. This could take a while.
#   Using cached tensorflow-2.13.0-cp38-cp38-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached tensorflow_intel-2.13.0-cp38-cp38-win_amd64.whl.metadata (4.1 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached h5py-3.11.0-cp38-cp38-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached numpy-1.24.3-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# ...

# %% [markdown]
# ## 2. Logistic Regression
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1, 3, 5, 7, 9, 11, 13])
y = np.array([0, 0, 0, 1, 1, 1, 1])

model = Sequential()
#model.add(Dense(10, input_dim=1, activation='relu')) # 은닉층 추가
model.add(Dense(1, input_dim = 1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
model.fit(x, y, epochs = 2000)

plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()

#inference
hours = 8
prediction = model.predict(np.array([hours]))
print('{}시간 공부하면 합격 확률은 {}입니다.'.format(hours, prediction))
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 252ms/step - loss: 1.1344
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9740
# Epoch 3/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8503
# Epoch 4/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7595
# Epoch 5/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6949
# Epoch 6/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6497
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6180
# Epoch 8/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5954
# Epoch 9/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5791
# Epoch 10/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5671
# Epoch 11/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5581
# Epoch 12/2000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

x = np.array([1, 3, 5, 7, 9, 11, 13])
y = np.array([0, 0, 0, 1, 1, 1, 1])

y_categorical = to_categorical(y, num_classes=2)

model = Sequential()
model.add(Dense(10, input_dim=1, activation='relu')) # 은닉층 추가
model.add(Dense(2, activation='softmax')) # 다중 클래스 분류, 2개의 출력 노드

model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x, y_categorical, epochs=2000)

plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()

# inference
hours = 8
prediction = model.predict(np.array([hours]))
print('{}시간 공부하면 합격 확률은 {}입니다.'.format(hours, prediction))
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 311ms/step - loss: 1.2160 - accuracy: 0.5714
# Epoch 2/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1334 - accuracy: 0.5714
# Epoch 3/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0540 - accuracy: 0.5714
# Epoch 4/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9780 - accuracy: 0.5714
# Epoch 5/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9056 - accuracy: 0.5714
# Epoch 6/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8372 - accuracy: 0.5714
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7735 - accuracy: 0.5714
# Epoch 8/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7150 - accuracy: 0.5714
# Epoch 9/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6626 - accuracy: 0.5714
# Epoch 10/2000
# ...

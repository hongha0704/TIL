# %% [markdown]
# # Classification Examples
# ---

# %% [markdown]
# ## 1. Binary Classification

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df.head(5) #print(df.head(5))
# Out:
# Mounted at /content/drive
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
# !pwd
# Out:
# /content

# %%
# !ls -al '/content/drive/MyDrive/Colab Notebooks/data'
# Out:
# total 869
# -rw------- 1 root root 460676 Jul 25  2022 house_train.csv
# -rw------- 1 root root   4466 Jul 21  2022 iris3.csv
# -rw------- 1 root root  23078 Jul 20  2022 pima-indians-diabetes3.csv
# -rw------- 1 root root  19015 Oct  5 01:06 ThoracicSurgery3.csv
# -r-------- 1 root root  19015 Jul  5  2023 ThoraricSurgery3.csv
# -rw------- 1 root root 361279 Jul 22  2022 wine.csv

# %%
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df['diabetes'].value_counts()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# diabetes
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df.describe()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df.corr()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
#df = pd.read_csv('./drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
print(df.head(5))

# heatmap setting
colormap = plt.cm.gist_heat
plt.figure(figsize = (12, 12))

# heatmap plotting
sns.heatmap(df.corr(), linewidth = 0.5, vmax = 0.5, cmap = colormap, annot=True)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df.head(5)
#df['diabetes'].value_counts()
#df.describe()
#df.corr()

plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins=30, histtype = 'barstacked', label = ['normal', 'diabetes'])
#plt.hist(x = [df.bmi[df.diabetes == 0], df.bmi[df.diabetes == 1]], bins = 30, histtype = 'barstacked', label = ['normal', 'diabetes'])
plt.legend()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
df.head(5)
#df['diabetes'].value_counts()
#df.describe()
#df.corr()

# plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins=30, histtype = 'barstacked', label = ['normal', 'diabetes'])
plt.hist(x = [df.bmi[df.diabetes == 0], df.bmi[df.diabetes == 1]], bins = 30, histtype = 'barstacked', label = ['normal', 'diabetes'])
plt.legend()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/pima-indians-diabetes3.csv')
X = df.iloc[:, 0:8] # column 0 - 7
y = df.iloc[:, 8] # column 8

model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(12, activation='relu', name='Dense_1'))
model.add(Dense(100, activation='relu', name='Dense_11'))
model.add(Dense(12, activation='relu', name='Dense_13'))
model.add(Dense(8, activation='relu', name='Dense_2'))
model.add(Dense(1, activation='sigmoid', name='Dense_3'))
model.summary()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Dense_1 (Dense)                      │ (None, 12)                  │             108 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_11 (Dense)                     │ (None, 100)                 │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_13 (Dense)                     │ (None, 12)                  │           1,212 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 100, batch_size = 10)
# Out:
# Epoch 1/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5988 - loss: 0.8000
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6402 - loss: 0.6787
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6595 - loss: 0.7221
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6574 - loss: 0.6560
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6615 - loss: 0.6506
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6660 - loss: 0.6276
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6723 - loss: 0.6347
# Epoch 8/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6956 - loss: 0.6736
# Epoch 9/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6930 - loss: 0.6073
# Epoch 10/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6754 - loss: 0.6130
# Epoch 11/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6745 - loss: 0.5971
# Epoch 12/100
# ...

# %% [markdown]
# ## Multiclass Classification

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/iris3.csv')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/iris3.csv')

sns.pairplot(df, hue='species')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/iris3.csv')

X = df.iloc[:, 0:4]
y = df.iloc[:, 4]
print(X.head(5)) # print(X[0:5])
print(y.head(5)) # print(y[0:5])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/iris3.csv')

X = df.iloc[:, 0:4]
y = df.iloc[:, 4]
y = pd.get_dummies(y) # one-hot encoding for y
#y = pd.get_dummies(y, prefix='species')
print(X.head(5))
print(y.head(5))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#    Iris-setosa  Iris-versicolor  Iris-virginica
# 0         True            False           False
# 1         True            False           False
# 2         True            False           False
# 3         True            False           False
# 4         True            False           False

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()
model.add(Input(shape=(4,)))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 12)                  │              60 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 8)                   │             104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 191 (764.00 B)
#  Trainable params: 191 (764.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# ...

# %% [markdown]
# # Practice

# %%
import pandas as pd

df = pd.read_csv("C:\Example\AI_Programming\pima-indians-diabetes3.csv")
df
# Out:
#      pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0           6     148        72         35        0  33.6     0.627   50
# 1           1      85        66         29        0  26.6     0.351   31
# 2           8     183        64          0        0  23.3     0.672   32
# 3           1      89        66         23       94  28.1     0.167   21
# 4           0     137        40         35      168  43.1     2.288   33
# ..        ...     ...       ...        ...      ...   ...       ...  ...
# 763        10     101        76         48      180  32.9     0.171   63
# 764         2     122        70         27        0  36.8     0.340   27
# 765         5     121        72         23      112  26.2     0.245   30
# 766         1     126        60          0        0  30.1     0.349   47
# 767         1      93        70         31        0  30.4     0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
df['diabetes'].value_counts()
# Out:
# diabetes
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
df.corr()
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colormap = plt.cm.gist_heat
plt.figure(figsize=(12, 12))

sns.heatmap(df.corr(), linewidths=0.5, vmax=0.5, cmap=colormap, annot=True)
plt.show()

# %%
plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins=30,
         histtype='barstacked', label=['normal', 'diabetes'])
plt.legend()
plt.show()

# %%
plt.hist(x=[df.bmi[df.diabetes==0], df.bmi[df.diabetes==1]], bins=30,
         histtype='barstacked', label=['normal', 'diabetes'])
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

X = df.iloc[:, 0:8]
y = df.iloc[:, 8]

model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(64, activation='relu', name='Dense_1'))
model.add(Dense(32, activation='relu', name='Dense_2'))
model.add(Dense(16, activation='relu', name='Dense_3'))
model.add(Dense(8, activation='relu', name='Dense_4'))
model.add(Dense(1, activation='sigmoid', name='Dense_5'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense_1 (Dense)             (None, 64)                576
#
#  Dense_2 (Dense)             (None, 32)                2080
#
#  Dense_3 (Dense)             (None, 16)                528
#
#  Dense_4 (Dense)             (None, 8)                 136
#
#  Dense_5 (Dense)             (None, 1)                 9
#
# ...
# Total params: 3329 (13.00 KB)
# Trainable params: 3329 (13.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, epochs=5000, batch_size=32)
# Out:
# Epoch 1/5000
# 24/24 [==============================] - 1s 1ms/step - loss: 0.2292 - accuracy: 0.9193
# Epoch 2/5000
# 24/24 [==============================] - 0s 965us/step - loss: 0.1575 - accuracy: 0.9362
# Epoch 3/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2450 - accuracy: 0.9154
# Epoch 4/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1532 - accuracy: 0.9388
# Epoch 5/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9714
# Epoch 6/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1078 - accuracy: 0.9609
# Epoch 7/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9492
# Epoch 8/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1390 - accuracy: 0.9414
# Epoch 9/5000
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9661
# Epoch 10/5000
# ...

# %%
df_history = pd.DataFrame(history.history)
df_history
# Out:
#           loss  accuracy
# 0     0.229218  0.919271
# 1     0.157488  0.936198
# 2     0.244973  0.915365
# 3     0.153185  0.938802
# 4     0.092072  0.971354
# ...        ...       ...
# 4995  0.007483  0.998698
# 4996  0.007282  0.997396
# 4997  0.007652  0.998698
# 4998  0.006567  0.998698
# 4999  0.007347  0.998698
#
# [5000 rows x 2 columns]

# %%
plt.subplot(2, 1, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.show()

plt.subplot(2, 1, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.show()

# %%
score = model.evaluate(X)
score

y_pred = model.predict(X)
y_pred

plt.figure()
plt.scatter(y, y_pred, alpha=0.5)
plt.xlabel('Actual Diabetes')
plt.ylabel('Prediction Diabetes')
plt.title('Actual vs Prediction Diabetes')
plt.show()

plt.figure()
plt.hist(y - y_pred.flatten(), bins=50, alpha=0.7, color='blue')
plt.xlabel('Residual (Actual - Predicted)')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()
# Out:
# ...
# 24/24 [==============================] - 0s 691us/step

# %%
df_iris = pd.read_csv("C:\Example\AI_Programming\iris3.csv")
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df_iris, hue='species')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df_iris.iloc[:, 0:4]
y= df_iris.iloc[:, 4]

y = pd.get_dummies(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Input(shape=(4,)))
model.add(Dense(12, activation='relu', name='Dense_1'))
model.add(Dense(8, activation='relu', name='Dense_2'))
model.add(Dense(3, activation='softmax', name='Dense_3'))
model.summary()

early_stopping_callback = EarlyStopping(monitor='val_loss', patience=50)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, epochs=500, batch_size=16, 
                    validation_split=0.25, callbacks=[early_stopping_callback])
# history = model.fit(X, y, epochs=100)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense_1 (Dense)             (None, 12)                60
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 3)                 27
#
# ...
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/500
# 7/7 [==============================] - 1s 25ms/step - loss: 1.0668 - accuracy: 0.3839 - val_loss: 2.0716 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0214 - accuracy: 0.1339 - val_loss: 2.1960 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0037 - accuracy: 0.2679 - val_loss: 2.2781 - val_accuracy: 0.0000e+00
# Epoch 4/500
# ...

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.figure()
plt.plot(loss, "o", markersize=2, label='Train Loss')
plt.plot(val_loss, "o", markersize=2, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.show()

plt.figure()
plt.plot(accuracy, "o", markersize=2, label='Train Accuracy')
plt.plot(val_accuracy, "o", markersize=2, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.show()

# %%
score = model.evaluate(X_test, y_test)
print('Loss     :', score[0])
print('Accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1085 - accuracy: 0.9667
# Loss     : 0.1085483729839325
# Accuracy : 0.9666666388511658

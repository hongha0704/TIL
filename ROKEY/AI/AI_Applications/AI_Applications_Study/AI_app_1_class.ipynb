# %%
import cv2
import numpy as np
import sys
import matplotlib.pyplot as plt
from pathlib import Path
print(cv2.__version__)
# Out:
# 4.10.0

# %%
folder = '../fig'

# %%
img = cv2.imread(Path(folder, 'dog.bmp'), cv2.IMREAD_COLOR)

if img is None:
    print('Image read failed')
    sys.exit()

print(type(img))
print(img.shape)
print(img.dtype)

cv2.imshow('dog', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (480, 640, 3)
# uint8

# %%
img = cv2.imread(Path(folder, 'dog.bmp'), cv2.IMREAD_COLOR)

print(img.shape[1], img.shape[0])

if img is None:
    print('Image read failed')
    sys.exit()

cv2.namedWindow('Dog', cv2.WINDOW_AUTOSIZE)

cv2.imshow('Dog', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 640 480

# %%
img = cv2.imread(Path(folder, 'dog.bmp'), cv2.IMREAD_COLOR)

if img is None:
    print('Image read failed')
    sys.exit()

cv2.namedWindow('dog', cv2.WINDOW_AUTOSIZE)
cv2.imshow('dog', img)

while True:
    if cv2.waitKey() == ord('q'):
        break

cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

img = cv2.imread(Path(folder, 'dog.bmp'), cv2.IMREAD_COLOR)
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

if img is None:
    print('Image read failed')
    sys.exit()

plt.figure(figsize=(10, 3))
plt.subplot(131), plt.imshow(img), plt.axis('off')
plt.subplot(132), plt.imshow(imgrgb), plt.axis('off')
plt.subplot(133), plt.imshow(imggray, cmap='gray'), plt.axis('off')
plt.show()

# %%
from urllib import request

url = "https://image.artbox.co.kr/upload/C00001/goods/800_800/179/241101006087179.jpg?s=/goods/org/179/241101006087179.jpg"
source = request.urlopen(url).read()

print(type(source))
print(source)
# Out:
# <class 'bytes'>
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x03 \x03 \x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x01\x02\x03\x05\x06\x00\x07\x08\xff\xc4\x00L\x10\x00\x02\x01\x03\x02\x04\x04\x03\x06\x04\x04\x04\x03\x06\x04\x07\x01\x02\x03\x00\x04\x11\x05!\x06\x121A\x13"Qa\x142q\x07#B\x81\x91\xa1\x15R\xb1\xc13b\xd1\xe1\x16$Cr4S\xf0%Ds\x82\x92\xf1\x17&T\x83\xa25cd\xb2\xc2\x93\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x00@\x11\x00\x02\x02\x01\x04\x01\x03\x02\x03\x06\x05\x04\x02\x01\x02\x07\x00\x01\x02\x03\x11\x04\x12!1A\x05\x13Q"a2q\x81\x14#\x91\xa1\xb1\xc1\x06BR\xd1\xf0\x153\xe1\xf1$b4\x16CS\xa2r\x92\xb2\xd2\xe2\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf2\xd2\xe4U\x18\'\x9236;\xd1\x80\xc8\xc37\xbd\x1bE\xb8\x85\xa6\xa7\x81n\x07y3RH\x83`\xce\xf9\xa9$G$D\xd4\x81\x0c4\xc6\x84\x07\x14\x0c\x95$\xc5&\x86\x98BKPh\xb12t\x97\xde\xa2\xd1$\xc2\x12\x7fz\x8e\t\xa6N\x93TZ\x1aaqI\x9a\x83E\x89\x87B\xd5^\t\xa0\xe8\x9a\xa2\xc9 \xe8Nj\x0c\x90|5\x064\x16\xa34\x86;\x96\x90\x1d\xcb@d\xe2\xb4\x01\xdc\xbbP\x04L)\x88\x89\xbaS@BN)\xe0\x06g4`y \x98li\xa0`N\xf85,\x11#\x12\xe0\xf5\xa3\x01\x90\x88g\xf7\xa4\xd0\xd3\x0e\x8aj\x83D\x82\x96m\xaa8\x01L\xb4\xb0\x04L\xf9\xcd<\x08\x16V\xd8\xd4\x90\x15\xf2\xb7Z\x90\x029\xa6\x04\x04\xd01\x99\xcd\x00(\xa0\x05\xa0\x05\x14\x868R\x01i\x80\xa2\x90\x0fZ\x06J\xb4\x80\x95)\x00BR\x00\x98\xe9\x08!)\x88!(\x10BR\x00\x84\xa6\x01QS"\x1b\x1d2!1\xf4\xa6"Q@\x87S\x11\xd4\x80i\xa0c\r!\x8c4\x00\xc3@\xc6\x1a@4\xd2\x01(\x01(\x18\xa2\x98\x0e\x14\x08Z\x00QL\x07\n\x04- \x12\x98\r4\x01\x13w\xa0`\xd2P4\t\'zD\x81\x9e\x90\xc8\xcd\x00% \x14P!h\x18\x86\x80\x1b@\t@\tH\x0e\xa0B\xd0\x07P3\x85\x00-1\n(\x01E\x008P\x03\x85\x00<P#\xcb\x9cWP\xe7\xb4\x0b&EI\x10h\x80\xbdH\x86H\x99\xe9\x91\xc9\x0b=4\x85\x92"i\x80\xd3L\x90\xca\x06!\xa0g\x03\x8a\x06=_\x14\xb0\x04\xab-,\x12L\x99f\xa8\xe0y\x08\x8eZ\x8bD\x93\x0f\x82J\xad\xa2\xc4\xcb8[j\xad\xa2\xd4\x1f\x0boU\xb2i\x960\x9a\x83\x19a\x0ej\x0c\x92\x0e\x8cmQ\x190Z`w-!\t\xcbH\x0e)@\xc8]i\x803\x8ah\x01\xdc\x1d\xeaHL\x81\x9b\x06\xa5\x81d\x86I2)\xa4\x19\x00\x91\xfa\xd3\xc0\xb2\n\xd2\xe2\xa4\x91\x1c\x8e\x8e\xe2\x93CR\x0e\x86\xe3\xde\xa0\xe2M0\xd4\x9bn\xb5\x0c\x12\x1f\xe2\xfb\xd2\xc0\r3Q\x80\x07\x92]\xa9\xa4 \x19d\x1b\xd4\x80\x11\x9e\x9e\x00\x8b\x9a\x81\x9d\x9a\x00Pi\x0cvh\x01A\xa41\xc2\x80\x1d@\x1c(\x02E\xa4\x04\xabHd\xcb@\x13\xa5DA)@\x82R\x80\'J\x04\x10\x94\x00Dt\x08**b\x0c\x8e\x9a"\xc2\x93\xa51\x12\x8ab\x17\x14\x01\xd4\x80i\xa0\x06\x9aC\x1ah\x01\x86\x81\x8c4\x80a\x14\r\t\x8a@u\x00(\xa0\x07P#\xb1L\x07\x01@\x0b@\n(\x11\xd4\xc0i\x1bP\x04L(\x184\x83jC@\x92w\xa0\x903R\x19\x11\xa0\x04\xa0\x05\x14\x08\xea@%\x00%\x03\x134\x80\xea\x00\xea\x00\xea`-\x00u\x02\x16\x90\x1dM\x00\xa2\x80\x1c(\x01\xc2\x81\x0f\x14\x01\xe5l\xd5\xd40\x10\xbe\xe2\x9a"\xc0\xe4\xd8\x9a\x9a)d\x0c\xd5$D\x8c\x9ab\x19A$4\x9a\x06\x84\xa6Hm\x03\x12\x81\x9d\x9a\x00P\xd8\xa0\x07\x07"\x90\x13\xc5.\xf4\x9a\x1ae\x95\xbc\xb5SE\x89\x96\xf6\xf2f\xaah\xb6,\xb4\xb7\xc95[,E\xb5\xbaf\xabd\x91g\n`T\t\xa0\xd8\x96\x8c\x08\x9b\x97jCG\x05\xa8\x8cp\x8e\x80;\xc3\xa4\x03\x1e-\xa8\x009""\x98\x03\xbc}jH@\x92Dji\x91\x02\x99\n\xa9\xa9!\x15s6\t\xa9\xa4A\xb0\td\xa9\xa4E\xb2%\x9f\x07\xad=\xa2R\r\x82\xe3\xde\xabq,\x8c\x8b\x08\xe7\xdb\xadV\xd1jd\xbe7\xbd,\x06F\x19\xbd\xe8\xc0d\x86I\xb6\xebF\x03 \xb2KO\x01\x90r\xd9\xa0bf\x80\x14\x1a@8\x1a\x06:\x80\x1c)\x0cx\xa41h\x01h\x01\xebH\t\x92\x90"t\xa4\x04\xe9@\x04GHA1\xd0 \x85\xa0\t\xd2\x80\x08J\x04\x15\x154 \xc8\xe9\x91\nJdI\x85\x02\x1c(\x01\r\x03\x1ah\x01\xa6\x90\xc6\x1a\x064\xd2\x01\x94\x00\xd3@\xc6\xd2\x03\xa8\x18\xa2\x81\n(\x10\xb4\xc0p\xa0\x0e\xa6!\xc2\x80:\x80 ...

# %%
image = np.array(bytearray(source), dtype=np.uint8)
print(image.shape)

image = cv2.imdecode(image, cv2.IMREAD_COLOR)
cv2.imwrite("Charistmas.png", image)

cv2.imshow('img', image)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (161202,)

# %%
import os

img_list = os.listdir(Path(folder, 'images'))

img_files = []

for i in img_list:
    img_dir = Path(folder, 'images', i)
    img_files.append(img_dir)


cv2.namedWindow('folder images', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('folder images', cv2.WND_PROP_FULLSCREEN,
                      cv2.WINDOW_FULLSCREEN)

idx = 0
while True:
    img = cv2.imread(img_files[idx], cv2.IMREAD_COLOR)
    cv2.imshow('folder images', img)

    if cv2.waitKey(3000) == 27:
        break

    idx += 1

    if idx >= len(img_files):
        idx = 0

cv2.destroyAllWindows()

# %%
img = cv2.imread(Path(folder, 'dog.bmp'), cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()

print(img.shape)

x = 320; y = 240
print(img[240, 320])

img[150:250, 250:500] = (125, 44, 66)

cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.imshow('image', img)

while True:
    if cv2.waitKey() == 27:
        break

cv2.destroyAllWindows()
# Out:
# (480, 640, 3)
# [ 0 14 40]

# %%
img2 = np.ones((1200, 800, 3), dtype=np.uint8)*255

cv2.imshow('rand ones', img2)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread(Path(folder, 'rose.jpg'), cv2.IMREAD_COLOR)

if img is None:
    print("image read failed")
    sys.exit()

img2 = img.copy()

img2[150:200, 200:300] = (255, 0, 0)

cv2.namedWindow('rose', cv2.WINDOW_AUTOSIZE)
cv2.imshow('rose', img)
cv2.imshow('rose copy', img2)

while True:
    if cv2.waitKey() == ord('q'):
        break

cv2.destroyAllWindows()

# %%
img = cv2.imread(Path(folder, "dog.bmp"), cv2.IMREAD_COLOR)

if img is None:
    print("image read failed")
    sys.exit()

dog_eye = img[150:250, 250:500]

cv2.circle(dog_eye, (50, 50), 30, (0, 0, 255), 5)
print(dog_eye.shape)

cv2.namedWindow('dog', cv2.WINDOW_NORMAL)
cv2.imshow('dog', img)
cv2.imshow('dog eye', dog_eye)

while True:
    if cv2.waitKey() == 27:
        break

cv2.destroyAllWindows()
# Out:
# (100, 250, 3)

# %%
src = cv2.imread(Path(folder, 'airplane.bmp'), cv2.IMREAD_COLOR)
mask = cv2.imread(Path(folder, 'mask_plane.bmp'), cv2.IMREAD_GRAYSCALE)
dst = cv2.imread(Path(folder, 'field.bmp'), cv2.IMREAD_COLOR)

print(dst.shape)

if src is None or mask is None or dst is None:
    print('images read failed')
    sys.exit()

cv2.copyTo(src, mask, dst)

cv2.imshow('src', src)
cv2.imshow('mask', mask)
cv2.imshow('dst', dst)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (400, 600, 3)

# %%
src = cv2.imread(Path(folder, 'sunglass.png'), cv2.IMREAD_UNCHANGED)

if src is None:
    print('Image read failed!')
    sys.exit()

mask = src[:,:,-1]
glass = src[:,:, 0:3]

cv2.imshow('src', src)
cv2.imshow('glass', glass)
cv2.imshow('mask', mask)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = np.ones((600, 1200, 3), np.uint8)*255
cv2.line(img, (100, 50), (300, 50), (0, 0, 255), 10, cv2.LINE_AA)
cv2.line(img, (300, 50), (200, 300), (0, 0, 255), 20, cv2.LINE_AA)
cv2.arrowedLine(img, (400, 50), (400, 300), (255, 0, 0), 10, cv2.LINE_AA)

cv2.rectangle(img, (200, 400, 200, 100), (0,0,255), 5, cv2.LINE_AA)

cv2.circle(img, (700, 300), 100, (255,0,255), -1)

cv2.ellipse(img, (500,100), (100,50), 10, 0, 360, (255,0,0), 2)

pts = np.array([[250, 200], [300, 200], [350, 300], [250, 300]])
cv2.polylines(img, [pts], True, (255,0,255), 2, cv2.LINE_AA)

text = 'OpenCV version=4.9'
cv2.putText(img, text, (700,100), cv2.FONT_ITALIC, 1, (0,0,255), 2, cv2.LINE_AA)

cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread(Path(folder, "lenna.png"), cv2.IMREAD_COLOR)

if src is None:
    print("image read failed")
    sys.exit()

dst = cv2.add(src, 100)
dst2 = cv2.add(src, (0,0,250,0))

cv2.imshow('src', src)
cv2.imshow('dst', dst)
cv2.imshow('dst2', dst2)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src1 = cv2.imread(Path(folder, "lenna.png"), cv2.IMREAD_GRAYSCALE)
src2 = np.zeros((220,220), np.uint8)
print(src1.shape)
cv2.circle(src2, (110,110), 80, 200, -1)
cv2.circle(src2, (110,110), 40, 50, -1)

if src1 is None or src2 is None:
    print("image read failed")
    sys.exit()

dst1 = cv2.add(src1, src2)
dst2 = cv2.subtract(src1, src2)
dst3 = cv2.addWeighted(src1, 0.8, src2, 0.2, 0.0)
dst4 = cv2.absdiff(src1, src2)
dst5 = cv2.divide(src1, 2)
dst6 = cv2.multiply(src1, 2)

cv2.imshow('src1', src1)
cv2.imshow('src2', src2)
cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.imshow('dst3', dst3)
cv2.imshow('dst4', dst4)
cv2.imshow('dst5', dst5)
cv2.imshow('dst6', dst6)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (220, 220)

# %%
src = cv2.imread(Path(folder, "rose.jpg"), cv2.IMREAD_COLOR)

background = np.ones_like(src)*255

weight = np.arange(0, 1, 0.01)

for i in weight:
    dst = cv2.addWeighted(src, i, background, 1-i, 0.0)
    cv2.imshow('dst',dst)

    if cv2.waitKey(100) == 27:
        break

cv2.destroyAllWindows()

# %%
src = cv2.imread(Path(folder, "lenna.png"), cv2.IMREAD_COLOR)

if src is None:
    print("Image read failed")
    sys.exit()

hist_b = cv2.calcHist([src], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([src], [1], None, [256], [0, 255])
hist_r = cv2.calcHist([src], [2], None, [256], [0, 255])

plt.bar(np.arange(len(hist_b)), hist_b[:, 0], color='b', alpha=0.5)
plt.bar(np.arange(len(hist_g)), hist_g[:, 0], color='g', alpha=0.5)
plt.bar(np.arange(len(hist_r)), hist_r[:, 0], color='r', alpha=0.5)

cv2.imshow("lenna", src)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread(Path(folder, "puppy_shrink.png"))

if src is None:
    print('Image load failed!')
    sys.exit()

dst_norm = cv2.normalize(src, None, 0, 255, cv2.NORM_MINMAX, -1)

hist = cv2.calcHist([src], [0], None, [256], [0, 256])
hist_norm = cv2.calcHist([dst_norm], [0], None, [256], [0, 256])

plt.bar(np.arange(len(hist)), hist[:, 0], color='g', alpha=0.5)
plt.bar(np.arange(len(hist_norm)), hist_norm[:, 0], color='b', alpha=0.5)

cv2.imshow('src', src)
cv2.imshow('dst_norm', dst_norm)

cv2.waitKey()
cv2.destroyAllWindows()
